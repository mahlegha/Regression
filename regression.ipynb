# %% [markdown]
# <a href="https://colab.research.google.com/github/mahlegha/Regression/blob/main/regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn import linear_model
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("co2.csv")

# %%
df.describe()
# Out:
#            engine     cylandr    fuelcomb        out1
# count  500.000000  500.000000  500.000000  500.000000
# mean     3.600400    6.132000   12.476600  268.026000
# std      1.478191    1.832291    3.943025   67.099673
# min      1.000000    4.000000    4.800000  110.000000
# 25%      2.000000    4.000000    9.500000  217.000000
# 50%      3.600000    6.000000   11.650000  260.000000
# 75%      5.000000    8.000000   14.800000  317.000000
# max      6.800000   12.000000   25.800000  488.000000

# %%
df.head(10)
# Out:
#    engine  cylandr  fuelcomb  out1
# 0     2.0        4       8.5   196
# 1     2.4        4       9.6   221
# 2     1.5        4       5.9   136
# 3     3.5        6      11.1   255
# 4     3.5        6      10.6   244
# 5     3.5        6      10.0   230
# 6     3.5        6      10.1   232
# 7     3.7        6      11.1   255
# 8     3.7        6      11.6   267
# 9     2.4        4       9.2   212

# %%
x = df.drop('out1', axis=1)
# x = x.drop('fuelcomb', axis=1)
# x = x.drop('cylandr', axis=1)
y = df.out1

# %%
x
# Out:
#      engine  cylandr  fuelcomb
# 0       2.0        4       8.5
# 1       2.4        4       9.6
# 2       1.5        4       5.9
# 3       3.5        6      11.1
# 4       3.5        6      10.6
# ..      ...      ...       ...
# 495     1.5        4       6.9
# 496     1.5        4       7.5
# 497     1.5        4       7.7
# 498     3.5        6      10.6
# 499     3.6        6      10.8
#
# [500 rows x 3 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2)

# %%
X_test
# Out:
#      engine  cylandr  fuelcomb
# 482     2.4        4       8.1
# 454     4.3        6      16.8
# 439     5.3        8      16.5
# 219     5.3        8      16.5
# 255     1.8        4       8.3
# ..      ...      ...       ...
# 331     3.6        6      16.2
# 158     2.5        4       9.0
# 69      4.0        8      13.4
# 354     3.5        6      11.5
# 487     2.0        4       4.8
#
# [100 rows x 3 columns]

# %%
y_test
# Out:
# 482    186
# 454    269
# 439    380
# 219    380
# 255    191
#       ...
# 331    259
# 158    207
# 69     314
# 354    264
# 487    110
# Name: out1, Length: 100, dtype: int64

# %%
model = linear_model.LinearRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_test_pred = model.predict(X_test)

# %%
plt.scatter(X_test, y_test, color='red')
plt.plot(X_test, y_test_pred, color='black')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-74-f450c5e45677> in <cell line: 1>()
# ----> 1 plt.scatter(X_test, y_test, color='red')
#       2 plt.plot(X_test, y_test_pred, color='black')
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, data, **kwargs)
#    3685     **kwargs,
#    3686 ) -> PathCollection:
# -> 3687     __ret = gca().scatter(
#    3688         x,
#    3689         y,
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1463     def inner(ax, *args, data=None, **kwargs):
#    1464         if data is None:
# -> 1465             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1466
#    1467         bound = new_sig.bind(ax, *args, **kwargs)
#
# ...
